# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(""), '..', 'lime_ndt')))
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(""), '..')))

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from lime_ndt.lime_tabular import LimeTabularExplainer
from lime_ndt.utils.ndt_sklearn_wrapper import NDTClassifierWrapper

# Charger le dataset Iris
iris = load_iris()
X = iris.data
y = iris.target

# Séparer en train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Entraîner le modèle global Random Forest
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

# Fonction de prédiction globale utilisant le Random Forest
def predict_fn(X):
    return rf.predict_proba(X)

# Créer l'explainer LIME
explainer = LimeTabularExplainer(
    X_train,
    feature_names=iris.feature_names,
    class_names=iris.target_names,
    discretize_continuous=False,
    mode='classification',
)

# Créer le modèle local NDT
model_classifier = NDTClassifierWrapper(D=X_train.shape[1])

# Expliquer une instance
exp = explainer.explain_instance(
    X_test[0],
    predict_fn,
    num_features=4,
    model_regressor=model_classifier
)

print("Explication locale (feature, poids):")
print(exp.as_list())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 36
#      33 model_classifier = NDTClassifierWrapper(D=X_train.shape[1])
#      35 # Expliquer une instance
# ---> 36 exp = explainer.explain_instance(
#      37     X_test[0],
#      38     predict_fn,
#      39     num_features=4,
#      40     model_regressor=model_classifier
#      41 )
#      43 print("Explication locale (feature, poids):")
#      44 print(exp.as_list())
#
# File c:\Users\DELL\Desktop\lime_ndt\lime_ndt\lime_tabular.py:458, in LimeTabularExplainer.explain_instance(self, data_row, predict_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor, sampling_method)
#     453     labels = [0]
#     454 for label in labels:
#     455     (ret_exp.intercept[label],
#     456      ret_exp.local_exp[label],
#     457      ret_exp.score[label],
# --> 458      ret_exp.local_pred[label]) = self.base.explain_instance_with_data(
#     459             scaled_data,
#     460             yss,
#     461             distances,
#     462             label,
#     463             num_features,
#     464             model_regressor=model_regressor,
#     465             feature_selection=self.feature_selection)
#     467 if self.mode == "regression":
#     468     ret_exp.intercept[1] = ret_exp.intercept[0]
#
# File c:\Users\DELL\Desktop\lime_ndt\lime_ndt\lime_base.py:190, in LimeBase.explain_instance_with_data(self, neighborhood_data, neighborhood_labels, distances, label, num_features, feature_selection, model_regressor)
#     184 used_features = self.feature_selection(neighborhood_data,
#     185                                        labels_column,
#     186                                        weights,
#     187                                        num_features,
#     188                                        feature_selection)
#     189 easy_model = model_regressor
# --> 190 easy_model.fit(neighborhood_data[:, used_features],
#     191                labels_column, sample_weight=weights)
#     192 prediction_score = easy_model.score(
#     193     neighborhood_data[:, used_features],
#     194     labels_column, sample_weight=weights)
#     196 local_pred = easy_model.predict(neighborhood_data[0, used_features].reshape(1, -1))
#
# File c:\Users\DELL\Desktop\lime_ndt\lime_ndt\utils\ndt_sklearn_wrapper.py:61, in NDTClassifierWrapper.fit(self, X, y, sample_weight)
#      57 from sklearn.tree import DecisionTreeClassifier
#      58 self.ndt = NDTClassifier(num_features=self.D, gammas=self.gammas, tree_id=self.tree_id,
#      59                         sigma=self.sigma, gamma_activation=self.gamma_activation)
#      60 tree = DecisionTreeClassifier(max_depth=self.max_depth,
# ---> 61                              random_state=self.random_state).fit(X, y)
#      62 self.ndt.compute_matrices_and_biases(tree)
#      63 self.ndt.to_keras(loss='categorical_crossentropy')
#
# File c:\Users\DELL\Desktop\lime_ndt\.venv\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\DELL\Desktop\lime_ndt\.venv\lib\site-packages\sklearn\tree\_classes.py:1024, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     993 @_fit_context(prefer_skip_nested_validation=True)
#     994 def fit(self, X, y, sample_weight=None, check_input=True):
#     995     """Build a decision tree classifier from the training set (X, y).
#     996
#     997     Parameters
#    (...)
#    1021         Fitted estimator.
#    1022     """
# -> 1024     super()._fit(
#    1025         X,
#    1026         y,
#    1027         sample_weight=sample_weight,
#    1028         check_input=check_input,
#    1029     )
#    1030     return self
#
# File c:\Users\DELL\Desktop\lime_ndt\.venv\lib\site-packages\sklearn\tree\_classes.py:294, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     291 self.n_outputs_ = y.shape[1]
#     293 if is_classification:
# --> 294     check_classification_targets(y)
#     295     y = np.copy(y)
#     297     self.classes_ = []
#
# File c:\Users\DELL\Desktop\lime_ndt\.venv\lib\site-packages\sklearn\utils\multiclass.py:222, in check_classification_targets(y)
#     214 y_type = type_of_target(y, input_name="y")
#     215 if y_type not in [
#     216     "binary",
#     217     "multiclass",
#    (...)
#     220     "multilabel-sequences",
#     221 ]:
# --> 222     raise ValueError(
#     223         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     224         "classifier, which expects discrete classes on a "
#     225         "regression target with continuous values."
#     226     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
from lime.lime_tabular import LimeTabularExplainer

# Créer l'explainer LIME officiel
explainer_lime = LimeTabularExplainer(
    X_train,
    feature_names=iris.feature_names,
    class_names=iris.target_names,
    discretize_continuous=True,
    mode='regression',
)

# Expliquer une instance avec le modèle local Ridge par défaut de LIME
exp_ridge = explainer_lime.explain_instance(
    X_test[0],
    predict_fn,
    num_features=4
)

print("\nExplication locale avec Ridge (LIME officiel) (feature, poids):")
print(exp_ridge.as_list())
# Out:
# Explication locale avec Ridge (LIME officiel) (feature, poids):
# [('4.30 < petal length (cm) <= 5.10', 0.1660818962971642), ('0.30 < petal width (cm) <= 1.30', -0.0850988993750235), ('sepal width (cm) <= 2.80', 0.029102969942546564), ('5.80 < sepal length (cm) <= 6.40', -0.0011156338670155917)]

# %%
import matplotlib.pyplot as plt

exp.as_pyplot_figure()
plt.show()

exp_ridge.as_pyplot_figure()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 exp.as_pyplot_figure()
#       4 plt.show()
#       6 exp_ridge.as_pyplot_figure()
#
# NameError: name 'exp' is not defined
